# %% [markdown]
# ## Imports

# %%
# Standard imports
import numpy as np
from matplotlib import pyplot as plt
plt.style.use('seaborn-white')
import tensorflow as tf
import shutil
import os, sys
from time import time
import pandas as pd



from Jet_Observables import NSubJettiness, Thrust, Uniform, Disk, Ellipse, Point, NStructure
from src.Observables import CustomObservable
# # eKDS Stuff
# from src.Graph import Background, Circle, Disk
# from src.eKDS import Graph, eKDS, emd
from src.utils.plot_utils import load_data, plot, plot_event, make_gif, timer_func
from utils import load_dataset
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-37389cdb4fd0> in <module>
#       3 from matplotlib import pyplot as plt
#       4 plt.style.use('seaborn-white')
# ----> 5 import tensorflow as tf
#       6 import shutil
#       7 import os, sys
#
# ~/miniconda3/lib/python3.8/site-packages/tensorflow/__init__.py in <module>
#      39 import sys as _sys
#      40
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      43
#
# ~/miniconda3/lib/python3.8/site-packages/tensorflow/python/__init__.py in <module>
#      62
#      63 # Framework
# ---> 64 from tensorflow.python.framework.framework_lib import *  # pylint: disable=redefined-builtin
#      65 from tensorflow.python.framework.versions import *
#      66 from tensorflow.python.framework import config
#
# ~/miniconda3/lib/python3.8/site-packages/tensorflow/python/framework/framework_lib.py in <module>
#      50 from tensorflow.python.framework.random_seed import set_random_seed
#      51 from tensorflow.python.framework.sparse_tensor import convert_to_tensor_or_sparse_tensor
# ---> 52 from tensorflow.python.framework.importer import import_graph_def
#      53
#      54 # Utilities for working with Tensors
#
# ~/miniconda3/lib/python3.8/site-packages/tensorflow/python/framework/importer.py in <module>
#      26 from tensorflow.python.framework import device as pydev
#      27 from tensorflow.python.framework import errors
# ---> 28 from tensorflow.python.framework import function
#      29 from tensorflow.python.framework import op_def_registry
#      30 from tensorflow.python.framework import ops
#
# ~/miniconda3/lib/python3.8/site-packages/tensorflow/python/framework/function.py in <module>
#      35 from tensorflow.python.framework import ops
#      36 from tensorflow.python.ops import array_ops
# ---> 37 from tensorflow.python.ops import resource_variable_ops
#      38 from tensorflow.python.ops import variable_scope as vs
#      39 from tensorflow.python.util import compat
#
# ~/miniconda3/lib/python3.8/site-packages/tensorflow/python/ops/resource_variable_ops.py in <module>
#      44 from tensorflow.python.ops import math_ops
#      45 from tensorflow.python.ops import state_ops
# ---> 46 from tensorflow.python.ops import variables
#      47 # go/tf-wildcard-import
#      48 # pylint: disable=wildcard-import
#
# ~/miniconda3/lib/python3.8/site-packages/tensorflow/python/ops/variables.py in <module>
#      34 from tensorflow.python.framework import tensor_shape
#      35 from tensorflow.python.ops import array_ops
# ---> 36 from tensorflow.python.ops import control_flow_ops
#      37 from tensorflow.python.ops import gen_array_ops
#      38 from tensorflow.python.ops import gen_state_ops
#
# ~/miniconda3/lib/python3.8/site-packages/tensorflow/python/ops/control_flow_ops.py in <module>
#      43 from tensorflow.python.ops import control_flow_util as util
#      44 from tensorflow.python.ops import gen_array_ops
# ---> 45 from tensorflow.python.ops import gen_control_flow_ops
#      46 from tensorflow.python.ops import gen_logging_ops
#      47 from tensorflow.python.ops import gen_math_ops
#
# ~/miniconda3/lib/python3.8/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# ~/miniconda3/lib/python3.8/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~/miniconda3/lib/python3.8/importlib/_bootstrap.py in _load_unlocked(spec)
#
# ~/miniconda3/lib/python3.8/importlib/_bootstrap_external.py in exec_module(self, module)
#
# ~/miniconda3/lib/python3.8/importlib/_bootstrap_external.py in get_code(self, fullname)
#
# ~/miniconda3/lib/python3.8/importlib/_bootstrap_external.py in _compile_bytecode(data, name, bytecode_path, source_path)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Datasets
#
# This part of the code can be modified, as long as the final datasets have the same format! Doesn't have to be physics-themed

# %%
# Parameters
R = 0.5
beta = 1.0
N = 250
epochs = 75
mass_lower = 160
mass_upper = 240
eta_cut = 1.3
plot_dir = "results"



signal, signal_masses = load_dataset("../Datasets/top/v0/signal_train.npy", N, mass_lower, mass_upper, eta_cut)
background, background_masses = load_dataset("../Datasets/top/v0/background_train.npy", N, mass_lower, mass_upper, eta_cut)
events = [signal, background]
event_labels = ["signal", "background"]
colors = ["red", "blue"]


# 129.61017751974222
# 82.32532856708265
# 105.34154685618293
# 193.06221424719445
# 68.27776974326825
# 64.42292091142367
# 67.828360476
# 119.89042427850859
# 84.47663199772002
# 88.29818627399061
# 40.5884429825644
# 84.28558542157585
# 77.54496314374398
# 90.7599523719835
# 70.92201712867734
# 79.15466095519379
# 197.2159592491737
# 171.2703621155101
# 109.4647932638973
# 128.6824146940929
# 54.75736669142741
# 59.25144692046561
# 160.2599754741505
# 103.36266512379854
# 44.84381058257453
# 38.038775678976684
# 65.23855691819062
# 149.96099257834885
# 124.86692992472467
# 158.1578412312784
# 48.08491813710315
# 69.85518372992706
# 107.63061066370477
# 136.7807901886267
# 82.46420804113485
# 30.78954137750007
# 78.8770750206797
# 53.91466192877802
# 36.5558515742328
# 47.21851058114476
# 204.76196085507334
# 56.91332863800349
# 102.33058633262631
# 192.1614097583557
# 165.9296311509184
# 66.16755479039814
# 41.35729466921693
# 42.1897431004141
# 66.70307401296226
# 203.59818070415497
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-d342d4c3ee02> in <module>
#      12
#      13 signal, signal_masses = load_dataset("../Datasets/top/v0/signal_train.npy", N, mass_lower, mass_upper, eta_cut)
# ---> 14 background, background_masses = load_dataset("../Datasets/top/v0/background_train.npy", N, mass_lower, mass_upper, eta_cut)
#      15 events = [signal, background]
#      16 event_labels = ["signal", "background"]
#
# ~/Documents/Physics/Grad/Research/Simplex/eKDS/utils.py in load_dataset(filename, N, mass_lower, mass_upper, eta_cut)
#      25
#      26             mask = zs[:] > 0
# ---> 27             x[mask, 2] = np.unwrap(x[mask,2])
#      28             yphi_avg = np.average(x[mask,1:3], weights = x[mask,0], axis = 0)
#      29             x[mask,1:3] -= yphi_avg
#
# <__array_function__ internals> in unwrap(*args, **kwargs)
#
# ~/miniconda3/lib/python3.8/site-packages/numpy/lib/function_base.py in unwrap(p, discont, axis)
#    1543     _nx.copyto(ph_correct, 0, where=abs(dd) < discont)
#    1544     up = array(p, copy=True, dtype='d')
# -> 1545     up[slice1] = p[slice1] + ph_correct.cumsum(axis)
#    1546     return up
#    1547
#
# KeyboardInterrupt:

# %%
# Example plots
example_signal = signal[0]
plot_event(example_signal[0], example_signal[1], R, color = "red")

example_background = background[0]
plot_event(example_background[0], example_background[1], R, color = "blue")

plt.hist(signal_masses, color = "red", alpha = 0.5, label = "Top Jets", density = True)
plt.hist(background_masses, color = "blue", alpha = 0.5, label = "Light Jets", density = True)
plt.legend()

# %% [markdown]
# ## Observables

# %%
_1subjettinesss = NStructure(Point, N = 1, name = "1-Subjettiness", initializer = "kt", R = R, beta = beta)
_2subjettinesss = NStructure(Point, N = 2, name = "2-Subjettiness", initializer = "kt", R = R, beta = beta)
_3subjettinesss = NStructure(Point, N = 3, name = "3-Subjettiness", initializer = "kt", R = R, beta = beta)

training_config_dict = {"epochs" : 500,
                        "optimizer" : tf.keras.optimizers.Adam(lr = 0.01),
                        "verbose" : False,
                        "early_stop" : 100,
                        "resample" : True}

test_event = (np.array(((0.0,0.0), (-R, 0.0), (R, 0.0), )), np.array((1.0 / 3, 1.0 / 3, 1.0/ 3,)))

tau2 = _2subjettinesss.calculate(test_event,training_config_dict=training_config_dict, gif_filename="temp/_2.gif")["EMD"]
tau3 = _3subjettinesss.calculate(test_event,training_config_dict=training_config_dict, plot_filename="temp/_3.png")["EMD"]


# kt = _3subjettinesss.calculate(events[0][0],training_config_dict=training_config_dict)["EMD"]

emds = []
for i in range(100):
   
   t1 = time()
   tau2 = _2subjettinesss.calculate(events[0][i],training_config_dict=training_config_dict)
   tau3 = _3subjettinesss.calculate(events[0][i],training_config_dict=training_config_dict)
   print(tau3, tau2)
   t2 = time()
   print("Event %d" %i, "Value: %.3f" % (tau3["EMD"] / tau2["EMD"]), "Finished in %.3fs" % (t2 - t1))
# Out:
# {'EMD': 0.12343625837754212, 'Center_0': array([-0.01346514, -0.0463787 ]), 'z_0': 0.49402945092192424, 'Center_1': array([0.30306364, 0.05334494]), 'z_1': 0.27616779072341846, 'Center_2': array([-0.34260211,  0.00462722]), 'z_2': 0.22980275835465724} {'EMD': 0.27296143890105523, 'Center_0': array([-0.0212498 , -0.04389569]), 'z_0': 0.7247693115939695, 'Center_1': array([0.30074715, 0.05457085]), 'z_1': 0.2752306884060305}
# Event 0 Value: 0.452 Finished in 7.867s
# {'EMD': 0.15079343485955557, 'Center_0': array([0.03557412, 0.01310311]), 'z_0': 0.6152634925110149, 'Center_1': array([0.07599395, 0.14255516]), 'z_1': 0.25119827261194827, 'Center_2': array([-0.43517507, -0.33923846]), 'z_2': 0.13353823487703675} {'EMD': 0.20666746495765015, 'Center_0': array([0.04743453, 0.03798189]), 'z_0': 0.86642159997893, 'Center_1': array([-0.43633352, -0.33275941]), 'z_1': 0.13357840002107002}
# Event 1 Value: 0.730 Finished in 8.754s
# {'EMD': 0.33582535845858585, 'Center_0': array([-0.10502766,  0.04967363]), 'z_0': 0.5242872912866428, 'Center_1': array([ 0.28439519, -0.1461714 ]), 'z_1': 0.2959796088019834, 'Center_2': array([ 0.25437373, -0.17498731]), 'z_2': 0.17973309991137384} {'EMD': 0.3469146441105128, 'Center_0': array([-0.10476177,  0.04370033]), 'z_0': 0.5297344256366632, 'Center_1': array([ 0.26397573, -0.14991191]), 'z_1': 0.4702655743633368}
# Event 2 Value: 0.968 Finished in 6.719s
# {'EMD': 0.18978164411743723, 'Center_0': array([0.0716847 , 0.00155867]), 'z_0': 0.5116749372307492, 'Center_1': array([-0.30673778, -0.11405775]), 'z_1': 0.27283090490480594, 'Center_2': array([0.27055401, 0.31016162]), 'z_2': 0.21549415786444492} {'EMD': 0.38844585166198053, 'Center_0': array([0.07316991, 0.0011753 ]), 'z_0': 0.7272835468595611, 'Center_1': array([-0.3141741 , -0.10749529]), 'z_1': 0.272716453140439}
# Event 3 Value: 0.489 Finished in 9.296s
# {'EMD': 0.3244951406766714, 'Center_0': array([-0.0686576 ,  0.04548121]), 'z_0': 0.5982897555678492, 'Center_1': array([ 0.22762268, -0.13364791]), 'z_1': 0.199008808603634, 'Center_2': array([ 0.23445298, -0.23806091]), 'z_2': 0.20270143582851685} {'EMD': 0.42449498882275144, 'Center_0': array([ 0.20983057, -0.10338042]), 'z_0': 0.7101041734586704, 'Center_1': array([-0.32073641,  0.24421047]), 'z_1': 0.2898958265413297}
# Event 4 Value: 0.764 Finished in 9.186s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-2caee72dd000> in <module>
#      22    t1 = time()
#      23    tau2 = _2subjettinesss.calculate(events[0][i],training_config_dict=training_config_dict)
# ---> 24    tau3 = _3subjettinesss.calculate(events[0][i],training_config_dict=training_config_dict)
#      25    print(tau3, tau2)
#      26    t2 = time()
#
# ~/Documents/Physics/Grad/Research/Simplex/eKDS/src/Observables.py in calculate(self, event, training_config_dict, gif_filename, plot_filename)
#     135                 for shape in self.shapes:
#     136                     shape.t = shape.sample(shape.N)
# --> 137             l, x_ij, y_j, z_j, _ = shaper.train_step((y_i, z_i), True)
#     138             if verbose:
#     139                 print("Epoch %d: %.3f, z0 = %.3f" % (epoch, l, self.z))
#
# ~/Documents/Physics/Grad/Research/Simplex/eKDS/src/shaper.py in train_step(self, event, train_z, epsilon)
#      92             # print (tf.reduce_sum(z_j))
#      93             x_ij, l = self.encode(y_i, z_i, y_j, z_j)
# ---> 94             loss = emd_loss(y_i, y_j, x_ij, self.R, self.beta)
#      95
#      96         # Compute gradients and update shape parameters
#
# ~/miniconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~/miniconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     616       # In this case we have not created variables on the first call. So we can
#     617       # run the first trace but we should fail if variables are created.
# --> 618       results = self._stateful_fn(*args, **kwds)
#     619       if self._created_variables:
#     620         raise ValueError("Creating variables on a non-first call to a function"
#
# ~/miniconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# ~/miniconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1659       `args` and `kwargs`.
#    1660     """
# -> 1661     return self._call_flat(
#    1662         (t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1663          if isinstance(t, (ops.Tensor,
#
# ~/miniconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1691       default_graph.mark_as_unsaveable(self._func_graph.saving_errors)
#    1692
# -> 1693     if (tape.could_possibly_record() or
#    1694         hasattr(ops.get_default_graph(), "watch_variable")):
#    1695       for v in self._func_graph.variables:
#
# KeyboardInterrupt:

# %%
test_event = (np.array(((0.0,0.0), (-R, 0.0), (R, 0.0), )), np.array((1.0 / 3, 1.0 / 3, 1.0/ 3,)))

tau2 = _2subjettinesss.calculate(test_event,training_config_dict=training_config_dict, plot_filename="temp/_2.png")["EMD"]
tau3 = _3subjettinesss.calculate(test_event,training_config_dict=training_config_dict, plot_filename="temp/_3.png")["EMD"]
print(tau2, tau3)

tau2 = _2subjettinesss.calculate(events[0][2],training_config_dict=training_config_dict, plot_filename="temp/_2.png")["EMD"]
tau3 = _3subjettinesss.calculate(events[0][2],training_config_dict=training_config_dict, plot_filename="temp/_3.png")["EMD"]
print(tau2, tau3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-701272800c98> in <module>
#       1 test_event = (np.array(((0.0,0.0), (-R, 0.0), (R, 0.0), )), np.array((1.0 / 3, 1.0 / 3, 1.0/ 3,)))
#       2
# ----> 3 tau2 = _2subjettinesss.calculate(test_event,training_config_dict=training_config_dict, plot_filename="temp/_2.png")["EMD"]
#       4 tau3 = _3subjettinesss.calculate(test_event,training_config_dict=training_config_dict, plot_filename="temp/_3.png")["EMD"]
#       5 print(tau2, tau3)
#
# ~/Documents/Physics/Grad/Research/Simplex/eKDS/src/Observables.py in calculate(self, event, training_config_dict, gif_filename, plot_filename)
#     135                 for shape in self.shapes:
#     136                     shape.t = shape.sample(shape.N)
# --> 137             l, x_ij, y_j, z_j, _ = shaper.train_step((y_i, z_i), True)
#     138             if verbose:
#     139                 print("Epoch %d: %.3f, z0 = %.3f" % (epoch, l, self.z))
#
# ~/Documents/Physics/Grad/Research/Simplex/eKDS/src/shaper.py in train_step(self, event, train_z, epsilon)
#     120
#     121             # Update z's, then normalize
# --> 122             self.optimizer.apply_gradients(zip(gradients, self.z))
#     123             zs = []
#     124             for i, shape in enumerate(self.shapes):
#
# ~/miniconda3/lib/python3.8/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py in apply_gradients(self, grads_and_vars, name, experimental_aggregate_gradients)
#     476       # Create iteration if necessary.
#     477       with ops.init_scope():
# --> 478         self._create_all_weights(var_list)
#     479
#     480       if not grads_and_vars:
#
# ~/miniconda3/lib/python3.8/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py in _create_all_weights(self, var_list)
#     661     _ = self.iterations
#     662     self._create_hypers()
# --> 663     self._create_slots(var_list)
#     664
#     665   def __getattribute__(self, name):
#
# ~/miniconda3/lib/python3.8/site-packages/tensorflow/python/keras/optimizer_v2/adam.py in _create_slots(self, var_list)
#     154     # Separate for-loops to respect the ordering of slot variables from v1.
#     155     for var in var_list:
# --> 156       self.add_slot(var, 'm')
#     157     for var in var_list:
#     158       self.add_slot(var, 'v')
#
# ~/miniconda3/lib/python3.8/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py in add_slot(self, var, slot_name, initializer)
#     696     if slot_name not in self._slot_names:
#     697       self._slot_names.append(slot_name)
# --> 698     var_key = _var_key(var)
#     699     slot_dict = self._slots.setdefault(var_key, {})
#     700     weight = slot_dict.get(slot_name, None)
#
# ~/miniconda3/lib/python3.8/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py in _var_key(var)
#    1243   if hasattr(var, "_distributed_container"):
#    1244     var = var._distributed_container()
# -> 1245   if var._in_graph_mode:
#    1246     return var._shared_name
#    1247   return var._unique_id
#
# AttributeError: 'numpy.float64' object has no attribute '_in_graph_mode'

# %% [markdown]
# ## Run

# %%
# # TEST ON IDEAL EVENTS

# # Calculate the EMDs for each observable, for each event
# for (i, event_type) in enumerate(events):
#     for (j, obs) in enumerate(observables[1:2]):
#         for (k, event) in enumerate(events[i][0:2]):

#             t1 = time()
#             params = obs.calculate(event, training_config_dict, gif_filename = "temp/test_%s_%d_%s.gif" % (event_labels[i], k, obs.name), plot_filename="temp/%s/test_%d_%s.png" % (event_labels[i], k, obs.name))
#             print(params)
#             t2 = time()
#             print("Event %d" %k, "Obs: %s" % obs.name, "Class: %s" % event_labels[i], "Value: %.3f" % params["EMD"], "Finished in %.3fs" % (t2 - t1))

# %%
emds = np.zeros(shape = (len(events),len(observables), N))
param_dicts = [[],[], []]

# Calculate the EMDs for each observable, for each event
for (i, event_type) in enumerate(events):
    for (j, obs) in enumerate(observables):
        for (k, event) in enumerate(events[i]):

            t1 = time()
            params = obs.calculate(event, training_config_dict, plot_filename="temp/%s/test_%d_%s.png" % (event_labels[i], k, obs.name))
            emds[i,j,k] = params["EMD"]
            param_dicts[j].append(params)
            t2 = time()

            print("Event %d" %k, "Obs: %s" % obs.name, "Class: %s" % event_labels[i], "Value: %.3f" % params["EMD"], "Finished in %.3fs" % (t2 - t1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-801c7f8e9d76> in <module>
# ----> 1 emds = np.zeros(shape = (len(events),len(observables), N))
#       2 param_dicts = [[],[], []]
#       3
#       4 # Calculate the EMDs for each observable, for each event
#       5 for (i, event_type) in enumerate(events):
#
# NameError: name 'observables' is not defined

# %% [markdown]
# ## Plots

# %%
np.save("emds.npy", emds, )

df = pd.DataFrame(param_dicts[0])
df.to_csv("dataframe_3ellipsiness.csv")

# df = pd.DataFrame(param_dicts[1])
# df.to_csv("dataframe_1ellipsiness_plus_pileup.csv")

# df = pd.read_csv("dataframe_1ellipsiness.csv")
# print(df.head(10))


for (j, obs) in enumerate(observables):
    plt.hist(emds[0,j,:], bins = 25, range=(0.0, 1.0), density = True, color = "red", label = "Signal EMDs", histtype="stepfilled", alpha = 0.5)
    plt.hist(emds[1,j,:], bins = 25, range=(0.0, 1.0), density = True, color = "blue", label = "Background EMDs", histtype="stepfilled", alpha = 0.5)
    plt.title(obs.name)
    plt.xlabel(r"%s EMDs" % obs.name)
    plt.legend()
    plt.show()

# %%
for (j, obs) in enumerate(observables):
    plt.hist(emds[0,j+1,:] / emds[0,j,:], bins = 25, range=(0.0, 2.0), density = True, color = "red", label = "Signal EMDs", histtype="stepfilled", alpha = 0.5)
    plt.hist(emds[1,j+1,:] / emds[1,j,:], bins = 25, range=(0.0, 2.0), density = True, color = "blue", label = "Background EMDs", histtype="stepfilled", alpha = 0.5)
    plt.title(r"$\tau_{%d %d}$" % (j+2, j+1))
    plt.xlabel(r"$\tau_{%d %d}$" % (j+2, j+1))
    plt.legend()
    plt.show()

# %%
# AUC 
from sklearn import metrics

y = np.array([1]*N + [0]*N)
for j in range(len(observables)):
    pred = np.concatenate( (emds[0,j,:], emds[1,j,:]))
    fpr, tpr, thresholds = metrics.roc_curve(y, pred)
    plt.plot(fpr, tpr, label = "%s: %.3f" %(obs.name,metrics.auc(fpr, tpr) ))


def sigmoid(z):
    return 1/(1+np.exp(-z))

combos = ((0,1), (1,2), (0,2))
for combo in combos:
    pred = sigmoid(np.concatenate( (emds[0,combo[0],:], emds[1,combo[0],:])) / np.concatenate( (emds[0,combo[1],:], emds[1,combo[1],:])))
    fpr, tpr, thresholds = metrics.roc_curve(y, pred)
    plt.plot(fpr, tpr, label = "%d / %d: %.3f" % (combo[0]+1, combo[1]+1,metrics.auc(fpr, tpr) ))
# plt.plot(fpr, tpr, label = "%s: %.3f" %("1 / 3",metrics.auc(fpr, tpr) ))

plt.legend()
# plt.plot(fpr, tpr, label = "%s: %.3f" %("1 / 3",metrics.auc(fpr, tpr) ))

# %%
# Fancy plots
import seaborn as sns
import pandas as pd

df = pd.DataFrame(np.transpose(emds[0]), )
print(df.shape)
sns.pairplot(df)

df = pd.DataFrame(np.transpose(emds[1]), )
print(df.shape)
sns.pairplot(df)

# %%
import pandas as pd



df = pd.read_csv("dataframe_1ellipsiness_plus_pileup.csv")
eccentricities = df["eccentricity_1"]

signal_df = pd.read_csv("dataframe_3ellipsiness_signal.csv")
background_df = pd.read_csv("dataframe_3ellipsiness_background.csv")




observables = ["EMD"]
signal_eccentricities = np.amax(signal_df[observables].to_numpy(), axis = 1)
background_eccentricities = np.amax(background_df[observables].to_numpy(), axis = 1)
print(signal_eccentricities.shape, background_eccentricities)

plt.hist(signal_eccentricities, range = (0,1), bins = 15, density= True, alpha = 0.5, color = "red", label = "Top Jet")
plt.hist(background_eccentricities, range = (0,1), bins = 15, density= True, alpha = 0.5, color = "blue", label = "Light Jet")
